# %%
# !pip install numpy 
# !pip install pandas 
# !pip install chromedriver_binary
# !pip install beautifulsoup4
# !pip install selenium
# !pip install webdriver-manager
import numpy as np
import pandas as pd

from bs4 import BeautifulSoup
from selenium import webdriver

# %% [markdown]
# # All Video Scrapped !

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import chromedriver_binary
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
browser = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
browser.get('https://www.youtube.com/c/GeeksforGeeksVideos/videos')

# %%
 

soup = BeautifulSoup(browser.page_source, 'html.parser')

complete_video_details = []
 
for video in soup.find_all(class_='ytd-rich-item-renderer'):
    try:
         
        video_description = video.find('a', class_='yt-simple-endpoint focus-on-expand style-scope ytd-rich-grid-media')
        video_description = video_description.text.strip() if video_description else None
    except Exception as e:
        video_description = None 

    try:
       
        video_meta = video.find_all('span', class_='inline-metadata-item style-scope ytd-video-meta-block')
        video_views = video_meta[0].text.strip() if len(video_meta) > 0 else None
    except Exception as e:
        video_views = None 
    
    try:
        
        video_date = video_meta[1].text.strip() if len(video_meta) > 1 else None
    except Exception as e:
        video_date = None 

    try:
       
        video_url = 'https://www.youtube.com' + video.find_all('a')[0].get('href')
    except Exception as e:
        video_url = None 
    
    
    complete_video_details.append({
        'description': video_description,
        'views': video_views,
        'date': video_date,
        'url': video_url
    })

 
# for detail in complete_video_details:
#     print(detail)


df = pd.DataFrame(complete_video_details)
# Print the DataFrame
df = df.dropna()
df = df.drop_duplicates()

print(df)
df.to_csv("index1.csv", index=False)
# Out:
#                                           description       views  \
# 0   A Day in the Life at IIT: Struggles & Successe...   978 views
# 3   DSA was hard until i learned these 10 Patterns...  2.8K views
# 6   You're missing out by not starting the Three 9...  217K views
# 9   Which Programming Language should you learn in...  1.5K views
# 12  Your next 90 Days with Three 90 Challenge! | G...   36K views
# 15  How to Crack Gate CSE Exam in Just 30 Days ? |...  1.3K views
# 18         Three 90 Challenge Winners | GeeksforGeeks   510 views
# 21         Three 90 Challenge Winners | GeeksforGeeks   499 views
# 24  Three 90 Challenge by GeeksforGeeks | Commonly...   620 views
# 27         Three 90 Challenge Winners | GeeksforGeeks  1.1K views
# 30  Three 90 Challenge Winners | Real Stories | Ge...  3.2K views
# 33  Ready to take on the challenge? | 90% Refund C...  192K views
# 36  I went to the House of a Microsoft Software En...  4.9K views
# 39  The Only Cyber Security Roadmap you need for 2...  6.8K views
# 42  GeeksforGeeks is going to rock the world of Ed...  1.8K views
# 45  How to get a job in MAANG as a College Student...  4.9K views
# 48  Get your Dream Internship in the First Year of...   950 views
# 51  GfG Practice Channel Now Home to GfG 160 Chall...   764 views
# 54  GfG 160 | Day- 42 | Pair with given sum - 2Sum...   671 views
# 57  These 7 AI Projects will give you an UNFAIR Ad...  1.2K views
# 60  GfG 160 | Day- 41 | Set Matrix Zeroes | 160 Da...   543 views
# 63  GfG 160 | Day- 40 | Search in a Sorted Matrix ...   561 views
# 66        FREE GATE Test Series 2025 by GeeksforGeeks    2K views
# 69  GfG 160 | Day- 39 | Search in a row-wise sorte...   512 views
# 72  GfG 160 | Day- 38 | Search in a Row-wise and C...   565 views
# %%
videoDetails  = soup.find_all('span')
videoDetails
# Out:
# [<span itemprop="author" itemscope="" itemtype="http://schema.org/Person"><link href="http://www.youtube.com/@GeeksforGeeksVideos" itemprop="url"/><link content="GeeksforGeeks" itemprop="name"/></span>,
#  <span itemprop="thumbnail" itemscope="" itemtype="http://schema.org/ImageObject"><link href="https://i.ytimg.com/vi/Ioj_XA-_jIY/maxresdefault.jpg" itemprop="url"/><meta content="1280" itemprop="width"/><meta content="720" itemprop="height"/></span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" enable-background="new 0 0 24 24" focusable="false" height="24" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="m12.71 12 8.15 8.15-.71.71L12 12.71l-8.15 8.15-.71-.71L11.29 12 3.15 3.85l.71-.71L12 11.29l8.15-8.15.71.71L12.71 12z"></path></svg></div></span>,
#  <span class="text-divider style-scope ytd-miniplayer">•</span>,
#  <span class="style-scope ytd-miniplayer"></span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" focusable="false" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M7.41 15.41L12 10.83l4.59 4.58L18 14l-6-6-6 6z"></path></svg></div></span>,
#  <span class="style-scope ytd-playlist-panel-renderer" id="next-label"></span>,
#  <span class="index-message style-scope ytd-playlist-panel-renderer">NaN / NaN</span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" enable-background="new 0 0 24 24" focusable="false" height="24" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="m12.71 12 8.15 8.15-.71.71L12 12.71l-8.15 8.15-.71-.71L11.29 12 3.15 3.85l.71-.71L12 11.29l8.15-8.15.71.71L12.71 12z"></path></svg></div></span>,
#  <span class="text-divider style-scope ytd-miniplayer">•</span>,
#  <span class="style-scope ytd-miniplayer"></span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" focusable="false" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M7.41 15.41L12 10.83l4.59 4.58L18 14l-6-6-6 6z"></path></svg></div></span>,
#  <span class="style-scope ytd-playlist-panel-renderer" id="next-label"></span>,
#  <span class="index-message style-scope ytd-playlist-panel-renderer">NaN / NaN</span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" enable-background="new 0 0 24 24" focusable="false" height="24" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="m12.71 12 8.15 8.15-.71.71L12 12.71l-8.15 8.15-.71-.71L11.29 12 3.15 3.85l.71-.71L12 11.29l8.15-8.15.71.71L12.71 12z"></path></svg></div></span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" focusable="false" height="24" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M9 19H7V5h2Zm8-14h-2v14h2Z"></path></svg></div></span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" enable-background="new 0 0 24 24" focusable="false" height="24" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M17.5 12c0 2.14-1.5 3.92-3.5 4.38v-2.09c.88-.39 1.5-1.27 1.5-2.29s-.62-1.9-1.5-2.29V7.62c2 .46 3.5 2.24 3.5 4.38zM3 9v6h3.16L12 19.93V4.07L6.16 9H3z"></path></svg></div></span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" focusable="false" height="24" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M21 6H3V5h18v1zm0 5H3v1h18v-1zm0 6H3v1h18v-1z"></path></svg></div></span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" focusable="false" height="20" id="yt-ringo2-svg_yt6" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 93 20" width="93" xmlns="http://www.w3.org/2000/svg">
#  <g>
#  <path d="M14.4848 20C14.4848 20 23.5695 20 25.8229 19.4C27.0917 19.06 28.0459 18.08 28.3808 16.87C29 14.65 29 9.98 29 9.98C29 9.98 29 5.34 28.3808 3.14C28.0459 1.9 27.0917 0.94 25.8229 0.61C23.5695 0 14.4848 0 14.4848 0C14.4848 0 5.42037 0 3.17711 0.61C1.9286 0.94 0.954148 1.9 0.59888 3.14C0 5.34 0 9.98 0 9.98C0 9.98 0 14.65 0.59888 16.87C0.954148 18.08 1.9286 19.06 3.17711 19.4C5.42037 20 14.4848 20 14.4848 20Z" fill="#FF0033"></path>
#  <path d="M19 10L11.5 5.75V14.25L19 10Z" fill="white"></path>
#  </g>
#  <g id="youtube-paths_yt6">
.52 28,18 28,12.47 23.52,8 18,8 z m -4.68,4 4.53,0 c .35,0 .70,.14 .93,.37 l 5.84,5.84 c .23,.23 .37,.58 .37,.93 0,.35 -0.13,.67 -0.37,.90 L 20.06,24.62 C 19.82,24.86 19.51,25 19.15,25 c -0.35,0 -0.70,-0.14 -0.93,-0.37 L 12.37,18.78 C 12.13,18.54 12,18.20 12,17.84 L 12,13.31 C 12,12.59 12.59,12 13.31,12 z m .96,1.31 c -0.53,0 -0.96,.42 -0.96,.96 0,.53 .42,.96 .96,.96 .53,0 .96,-0.42 .96,-0.96 0,-0.53 -0.42,-0.96 -0.96,-0.96 z" fill-opacity="1"></path><path class="ytp-svg-shadow-fill" d="M 24.61,18.22 18.76,12.37 C 18.53,12.14 18.20,12 17.85,12 H 13.30 C 12.58,12 12,12.58 12,13.30 V 17.85 c 0,.35 .14,.68 .38,.92 l 5.84,5.85 c .23,.23 .55,.37 .91,.37 .35,0 .68,-0.14 .91,-0.38 L 24.61,20.06 C 24.85,19.83 25,19.50 25,19.15 25,18.79 24.85,18.46 24.61,18.22 z M 14.27,15.25 c -0.53,0 -0.97,-0.43 -0.97,-0.97 0,-0.53 .43,-0.97 .97,-0.97 .53,0 .97,.43 .97,.97 0,.53 -0.43,.97 -0.97,.97 z" fill="#000" fill-opacity="0.15"></path></svg></div><div class="ytp-cards-button-title">Shopping</div></span>,
#  <span class="ytp-cards-teaser-label"></span>,
#  <span class="ytp-doubletap-base-arrow"></span>,
#  <span class="ytp-doubletap-base-arrow"></span>,
#  <span class="ytp-doubletap-base-arrow"></span>,
#  <span>Pull up for precise seeking</span>,
#  <span></span>,
#  <span class="ytp-tooltip-text ytp-tooltip-text-no-title">6:43</span>,
#  <span></span>,
#  <span class="ytp-free-preview-countdown-timer-separator">•</span>,
#  <span></span>,
#  <span class="ytp-volume-area"><button aria-keyshortcuts="m" aria-label="Mute keyboard shortcut m" class="ytp-mute-button ytp-button" data-title-no-tooltip="Mute" title="Mute (m)"><svg height="100%" version="1.1" viewbox="0 0 36 36" width="100%"><use class="ytp-svg-shadow" xlink:href="#ytp-id-15"></use><use class="ytp-svg-shadow" xlink:href="#ytp-id-16"></use><defs><clippath id="ytp-svg-volume-animation-mask"><path d="m 14.35,-0.14 -5.86,5.86 20.73,20.78 5.86,-5.91 z"></path><path d="M 7.07,6.87 -1.11,15.33 19.61,36.11 27.80,27.60 z"></path><path class="ytp-svg-volume-animation-mover" d="M 9.09,5.20 6.47,7.88 26.82,28.77 29.66,25.99 z" transform="translate(0, 0)"></path></clippath><clippath id="ytp-svg-volume-animation-slash-mask"><path class="ytp-svg-volume-animation-mover" d="m -11.45,-15.55 -4.44,4.51 20.45,20.94 4.55,-4.66 z" transform="translate(0, 0)"></path></clippath></defs><path class="ytp-svg-fill ytp-svg-volume-animation-speaker" clip-path="url(#ytp-svg-volume-animation-mask)" d="M8,21 L12,21 L17,26 L17,10 L12,15 L8,15 L8,21 Z M19,14 L19,22 C20.48,21.32 21.5,19.77 21.5,18 C21.5,16.26 20.48,14.74 19,14 Z" fill="#fff" id="ytp-id-15"></path><path class="ytp-svg-fill ytp-svg-volume-animation-hider" clip-path="url(#ytp-svg-volume-animation-slash-mask)" d="M 9.25,9 7.98,10.27 24.71,27 l 1.27,-1.27 Z" fill="#fff" id="ytp-id-16" style="display: none;"></path></svg></button><div aria-label="Volume" aria-valuemax="100" aria-valuemin="0" aria-valuenow="17" aria-valuetext="17% volume" class="ytp-volume-panel" role="slider" tabindex="0" title="Volume"><div class="ytp-volume-slider" draggable="true" style="touch-action: none;"><div class="ytp-volume-slider-handle" style="left: 6.8px;"></div></div></div></span>,
#  <span class="ytp-time-wrapper"><span class="ytp-time-clip-icon"><svg height="100%" version="1.1" viewbox="0 0 24 24" width="100%"><path d="M22,3h-4l-5,5l3,3l6-6V3L22,3z M10.79,7.79C10.91,7.38,11,6.95,11,6.5C11,4.01,8.99,2,6.5,2S2,4.01,2,6.5S4.01,11,6.5,11 c0.45,0,.88-0.09,1.29-0.21L9,12l-1.21,1.21C7.38,13.09,6.95,13,6.5,13C4.01,13,2,15.01,2,17.5S4.01,22,6.5,22s4.5-2.01,4.5-4.5 c0-0.45-0.09-0.88-0.21-1.29L12,15l6,6h4v-2L10.79,7.79z M6.5,8C5.67,8,5,7.33,5,6.5S5.67,5,6.5,5S8,5.67,8,6.5S7.33,8,6.5,8z M6.5,19C5.67,19,5,18.33,5,17.5S5.67,16,6.5,16S8,16.67,8,17.5S7.33,19,6.5,19z"></path></svg></span><span class="ytp-time-current">0:06</span><span class="ytp-time-separator"> / </span><span class="ytp-time-duration">8:05</span></span>,
#  <span class="ytp-time-clip-icon"><svg height="100%" version="1.1" viewbox="0 0 24 24" width="100%"><path d="M22,3h-4l-5,5l3,3l6-6V3L22,3z M10.79,7.79C10.91,7.38,11,6.95,11,6.5C11,4.01,8.99,2,6.5,2S2,4.01,2,6.5S4.01,11,6.5,11 c0.45,0,.88-0.09,1.29-0.21L9,12l-1.21,1.21C7.38,13.09,6.95,13,6.5,13C4.01,13,2,15.01,2,17.5S4.01,22,6.5,22s4.5-2.01,4.5-4.5 c0-0.45-0.09-0.88-0.21-1.29L12,15l6,6h4v-2L10.79,7.79z M6.5,8C5.67,8,5,7.33,5,6.5S5.67,5,6.5,5S8,5.67,8,6.5S7.33,8,6.5,8z M6.5,19C5.67,19,5,18.33,5,17.5S5.67,16,6.5,16S8,16.67,8,17.5S7.33,19,6.5,19z"></path></svg></span>,
#  <span class="ytp-time-current">0:06</span>,
#  <span class="ytp-time-separator"> / </span>,
#  <span class="ytp-time-duration">8:05</span>,
#  <span class="ytp-clip-watch-full-video-button-separator">•</span>,
#  <span class="ytp-clip-watch-full-video-button">Watch full video</span>,
#  <span aria-hidden="true" class="ytp-chapter-title-prefix">•</span>,
#  <span aria-hidden="true" class="ytp-chapter-title-prefix">•</span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" enable-background="new 0 0 24 24" focusable="false" height="24" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M21 6H3V5h18v1zm-6 5H3v1h12v-1zm-6 6H3v1h6v-1z"></path></svg></div></span>,
#  <span class="notification style-scope yt-dropdown-menu" hidden=""></span>,
#  <span class="notification style-scope yt-dropdown-menu" hidden=""></span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" enable-background="new 0 0 24 24" focusable="false" height="24" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="m
a></span><span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(19, 19, 19);"> </span><span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(6, 95, 212);"><a class="yt-core-attributed-string__link yt-core-attributed-string__link--call-to-action-color" force-new-state="true" href="/hashtag/iitmotivation" tabindex="0" target="">#iitmotivation</a></span><span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(19, 19, 19);"> </span><span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(6, 95, 212);"><a class="yt-core-attributed-string__link yt-core-attributed-string__link--call-to-action-color" force-new-state="true" href="/hashtag/engineeringlife" tabindex="0" target="">#engineeringlife</a></span><span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(19, 19, 19);"> </span><span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(6, 95, 212);"><a class="yt-core-attributed-string__link yt-core-attributed-string__link--call-to-action-color" force-new-state="true" href="/hashtag/gateexam" tabindex="0" target="">#gateexam</a></span><span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(19, 19, 19);"> </span><span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(6, 95, 212);"><a class="yt-core-attributed-string__link yt-core-attributed-string__link--call-to-action-color" force-new-state="true" href="/hashtag/gatestudyplan" tabindex="0" target="">#gatestudyplan</a></span><sp ...
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(19, 19, 19);">Watch Full Video: - </span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(19, 19, 19);"><span class="yt-core-attributed-string--highlight-text-decorator" dir="auto" style="background-color: rgba(0,0,0,0.051); border-radius: 8px; padding-bottom: 1px;"><a aria-label="YouTube Channel Link: Life at IIT: Struggles, Successes &amp; E..." class="yt-core-attributed-string__link yt-core-attributed-string__link--call-to-action-color" force-new-state="true" href="/watch?v=Ko4-1qYhsY0&amp;t=0s" tabindex="0" target="">  <span class="yt-core-attributed-string--inline-block-mod" style="margin-top: 0.5px;"><img alt="" class="yt-core-image yt-core-attributed-string__image-element yt-core-attributed-string__image-element--image-alignment-vertical-center yt-core-image--content-mode-scale-to-fill" style="height: 10px; width: 14px;"/></span> • Life at IIT: Struggles, Successes &amp; E...  </a></span></span>,
#  <span class="yt-core-attributed-string--highlight-text-decorator" dir="auto" style="background-color: rgba(0,0,0,0.051); border-radius: 8px; padding-bottom: 1px;"><a aria-label="YouTube Channel Link: Life at IIT: Struggles, Successes &amp; E..." class="yt-core-attributed-string__link yt-core-attributed-string__link--call-to-action-color" force-new-state="true" href="/watch?v=Ko4-1qYhsY0&amp;t=0s" tabindex="0" target="">  <span class="yt-core-attributed-string--inline-block-mod" style="margin-top: 0.5px;"><img alt="" class="yt-core-image yt-core-attributed-string__image-element yt-core-attributed-string__image-element--image-alignment-vertical-center yt-core-image--content-mode-scale-to-fill" style="height: 10px; width: 14px;"/></span> • Life at IIT: Struggles, Successes &amp; E...  </a></span>,
#  <span class="yt-core-attributed-string--inline-block-mod" style="margin-top: 0.5px;"><img alt="" class="yt-core-image yt-core-attributed-string__image-element yt-core-attributed-string__image-element--image-alignment-vertical-center yt-core-image--content-mode-scale-to-fill" style="height: 10px; width: 14px;"/></span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(19, 19, 19);">
#
#  Don't wait no more, and explore the GATE programs that are on offer now: </span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(6, 95, 212);"><a class="yt-core-attributed-string__link yt-core-attributed-string__link--call-to-action-color" force-new-state="true" href="https://www.youtube.com/redirect?event=video_description&amp;redir_token=QUFFLUhqbWtsakJ4YWF3YkFWNnFuRktNU1JlRnVIZk5lQXxBQ3Jtc0tudjk0VzN6b2tJVVFvSWN3Z2dXMUwtbmVqM1ZXOG5CNGFOZFAyWElFT19ZckZEeWQxSFE0VE4wU1RDbF9hT1c2ZTk1bzczdWMwRWh6clJJVllFU2JSb0g5UzBLN2pzWko5TzVuSEg5UnlEWUM4OHRGdw&amp;q=https%3A%2F%2Fgfgcdn.com%2Ftu%2FU4T%2F&amp;v=Ioj_XA-_jIY" rel="nofollow" tabindex="0" target="_blank">https://gfgcdn.com/tu/U4T/</a></span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(19, 19, 19);">
#
#  Ever wondered what a day in the life of an IITian looks like? In this video, we take you through the highs and lows of daily life at IIT, featuring Apoorva, who secured GATE AIR 20! From challenging academics to moments of success, watch as Apoorva shares their journey, struggles, and triumphs. Whether you're aiming for IIT or just curious about student life, this video gives you an inside look into the reality. Don’t forget to like, comment, and subscribe for more inspiring stories! 🎓🔥💡
#
#
#  </span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(6, 95, 212);"><a class="yt-core-attributed-string__link yt-core-attributed-string__link--call-to-action-color" force-new-state="true" href="/hashtag/iitlife" tabindex="0" target="">#iitlife</a></span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(19, 19, 19);"> </span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(6, 95, 212);"><a class="yt-core-attributed-string__link yt-core-attributed-string__link--call-to-action-color" force-new-state="true" href="/hashtag/gatesuccess" tabindex="0" target="">#gatesuccess</a></span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(19, 19, 19);"> </span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(6, 95, 212);"><a class="yt-core-attributed-string__link yt-core-attributed-string__link--call-to-action-color" force-new-state="true" href="/hashtag/studentjourney" tabindex="0" target="">#studentjourney</a></span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(19, 19, 19);"> </span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(6, 95, 212);"><a class="yt-core-attributed-string__link yt-core-attributed-string__link--call-to-action-color" force-new-state="true" href="/hashtag/iitstruggles" tabindex="0" target="">#IITStruggles</a></span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(19, 19, 19);"> </span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(6, 95, 212);"><a class="yt-core-attributed-string__link yt-core-attributed-string__link--call-to-action-color" force-new-state="true" href="/hashtag/successstory" tabindex="0" target="">#successstory</a></span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(19, 19, 19);"> </span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(6, 95, 212);"><a class="yt-core-attributed-string__link yt-core-attributed-string__link--call-to-action-color" force-new-state="true" href="/hashtag/gatepreparation" tabindex="0" target="">#gatepreparation</a></span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(19, 19, 19);"> </span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(6, 95, 212);"><a class="yt-core-attributed-string__link yt-core-attributed-string__link--call-to-action-color" force-new-state="true" href="/hashtag/iitmotivation" tabindex="0" target="">#iitmotivation</a></span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(19, 19, 19);"> </span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(6, 95, 212);"><a class="yt-core-attributed-string__link yt-core-attributed-string__link--call-to-action-color" force-new-state="true" href="/hashtag/engineeringlife" tabindex="0" target="">#engineeringlife</a></span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(19, 19, 19);"> </span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(6, 95, 212);"><a class="yt-core-attributed-string__link yt-core-attributed-string__link--call-to-action-color" force-new-state="true" href="/hashtag/gateexam" tabindex="0" target="">#gateexam</a></span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(19, 19, 19);"> </span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(6, 95, 212);"><a class="yt-core-attributed-string__link yt-core-attributed-string__link--call-to-action-color" force-new-state="true" href="/hashtag/gatestudyplan" tabindex="0" target="">#gatestudyplan</a></span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(19, 19, 19);"> </span>,
#  <span class="yt-core-attributed-string--link-inherit-color" dir="auto" style="color: rgb(6, 95, 212);"><a class="yt-core-attributed-string__link yt-core-attributed-string__link--call-to-action-color" force-new-state="true" href="/hashtag/gate2025" tabindex="0" target="">#gate2025</a></span>,
# ...
#  <span aria-label="25 minutes, 50 seconds" class="style-scope ytd-thumbnail-overlay-time-status-renderer" id="text">
#      25:50
#    </span>,
#  <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer" id="overlay-text">Now playing</span>,
#  <span aria-label="Find the School Playboy | Sach ya Scam | SlayyPop by SlayyPop 602,535 views 1 day ago 25 minutes" class="style-scope ytd-compact-video-renderer style-scope ytd-compact-video-renderer" id="video-title" title="Find the School Playboy | Sach ya Scam | SlayyPop">
#              Find the School Playboy | Sach ya Scam | SlayyPop
#            </span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" focusable="false" height="24" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 2C6.5 2 2 6.5 2 12s4.5 10 10 10 10-4.5 10-10S17.5 2 12 2zM9.8 17.3l-4.2-4.1L7 11.8l2.8 2.7L17 7.4l1.4 1.4-8.6 8.5z"></path></svg></div></span>,
#  <span class="inline-metadata-item style-scope ytd-video-meta-block">602K views</span>,
#  <span class="inline-metadata-item style-scope ytd-video-meta-block">1 day ago</span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" enable-background="new 0 0 24 24" focusable="false" height="24" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 16.5c.83 0 1.5.67 1.5 1.5s-.67 1.5-1.5 1.5-1.5-.67-1.5-1.5.67-1.5 1.5-1.5zM10.5 12c0 .83.67 1.5 1.5 1.5s1.5-.67 1.5-1.5-.67-1.5-1.5-1.5-1.5.67-1.5 1.5zm0-6c0 .83.67 1.5 1.5 1.5s1.5-.67 1.5-1.5-.67-1.5-1.5-1.5-1.5.67-1.5 1.5z"></path></svg></div></span>,
#  <span aria-label="23 minutes, 56 seconds" class="style-scope ytd-thumbnail-overlay-time-status-renderer" id="text">
#      23:56
#    </span>,
#  <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer" id="overlay-text">Now playing</span>,
#  <span aria-label="She started DSA in TCS and cracked Samsung and Microsoft | 7LPA to 35LPA by Fraz 339,836 views 5 months ago 23 minutes" class="style-scope ytd-compact-video-renderer style-scope ytd-compact-video-renderer" id="video-title" title="She started DSA in TCS and cracked Samsung and Microsoft | 7LPA to 35LPA">
#              She started DSA in TCS and cracked Samsung and Microsoft | 7LPA to 35LPA
#            </span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" focusable="false" height="24" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 2C6.5 2 2 6.5 2 12s4.5 10 10 10 10-4.5 10-10S17.5 2 12 2zM9.8 17.3l-4.2-4.1L7 11.8l2.8 2.7L17 7.4l1.4 1.4-8.6 8.5z"></path></svg></div></span>,
#  <span class="inline-metadata-item style-scope ytd-video-meta-block">339K views</span>,
#  <span class="inline-metadata-item style-scope ytd-video-meta-block">5 months ago</span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" enable-background="new 0 0 24 24" focusable="false" height="24" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 16.5c.83 0 1.5.67 1.5 1.5s-.67 1.5-1.5 1.5-1.5-.67-1.5-1.5.67-1.5 1.5-1.5zM10.5 12c0 .83.67 1.5 1.5 1.5s1.5-.67 1.5-1.5-.67-1.5-1.5-1.5-1.5.67-1.5 1.5zm0-6c0 .83.67 1.5 1.5 1.5s1.5-.67 1.5-1.5-.67-1.5-1.5-1.5-1.5.67-1.5 1.5z"></path></svg></div></span>,
#  <span aria-label="28 minutes, 19 seconds" class="style-scope ytd-thumbnail-overlay-time-status-renderer" id="text">
#      28:19
#    </span>,
#  <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer" id="overlay-text">Now playing</span>,
#  <span aria-label="R&amp;AW vs ISI : Exposing SECRET RIVALRY Since Independence by Gaurav Thakur 167,735 views 10 hours ago 28 minutes" class="style-scope ytd-compact-video-renderer style-scope ytd-compact-video-renderer" id="video-title" title="R&amp;AW vs ISI : Exposing SECRET RIVALRY Since Independence">
#              R&amp;AW vs ISI : Exposing SECRET RIVALRY Since Independence
#            </span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" focusable="false" height="24" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 2C6.5 2 2 6.5 2 12s4.5 10 10 10 10-4.5 10-10S17.5 2 12 2zM9.8 17.3l-4.2-4.1L7 11.8l2.8 2.7L17 7.4l1.4 1.4-8.6 8.5z"></path></svg></div></span>,
#  <span class="inline-metadata-item style-scope ytd-video-meta-block">167K views</span>,
#  <span class="inline-metadata-item style-scope ytd-video-meta-block">10 hours ago</span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" enable-background="new 0 0 24 24" focusable="false" height="24" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 16.5c.83 0 1.5.67 1.5 1.5s-.67 1.5-1.5 1.5-1.5-.67-1.5-1.5.67-1.5 1.5-1.5zM10.5 12c0 .83.67 1.5 1.5 1.5s1.5-.67 1.5-1.5-.67-1.5-1.5-1.5-1.5.67-1.5 1.5zm0-6c0 .83.67 1.5 1.5 1.5s1.5-.67 1.5-1.5-.67-1.5-1.5-1.5-1.5.67-1.5 1.5z"></path></svg></div></span>,
#  <span aria-label="30 minutes, 45 seconds" class="style-scope ytd-thumbnail-overlay-time-status-renderer" id="text">
#      30:45
#    </span>,
#  <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer" id="overlay-text">Now playing</span>,
#  <span aria-label="IIT prof reacts to his own student's video (Tharun Speaks)! by jc 2,637,994 views 3 years ago 30 minutes" class="style-scope ytd-compact-video-renderer style-scope ytd-compact-video-renderer" id="video-title" title="IIT prof reacts to his own student's video (Tharun Speaks)!">
#              IIT prof reacts to his own student's video (Tharun Speaks)!
#            </span>,
#  <span class="inline-metadata-item style-scope ytd-video-meta-block">2.6M views</span>,
#  <span class="inline-metadata-item style-scope ytd-video-meta-block">3 years ago</span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" enable-background="new 0 0 24 24" focusable="false" height="24" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 16.5c.83 0 1.5.67 1.5 1.5s-.67 1.5-1.5 1.5-1.5-.67-1.5-1.5.67-1.5 1.5-1.5zM10.5 12c0 .83.67 1.5 1.5 1.5s1.5-.67 1.5-1.5-.67-1.5-1.5-1.5-1.5.67-1.5 1.5zm0-6c0 .83.67 1.5 1.5 1.5s1.5-.67 1.5-1.5-.67-1.5-1.5-1.5-1.5.67-1.5 1.5z"></path></svg></div></span>,
#  <span aria-label="21 minutes, 55 seconds" class="style-scope ytd-thumbnail-overlay-time-status-renderer" id="text">
#      21:55
#    </span>,
#  <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer" id="overlay-text">Now playing</span>,
#  <span aria-label="How she cracked Google Summer of Code in First year in 1 month! 🚀 | GSoC Guide by Nishant Chahar 155,712 views 8 months ago 21 minutes" class="style-scope ytd-compact-video-renderer style-scope ytd-compact-video-renderer" id="video-title" title="How she cracked Google Summer of Code in First year in 1 month! 🚀 | GSoC Guide">
#              How she cracked Google Summer of Code in First year in 1 month! 🚀 | GSoC Guide
#            </span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" focusable="false" height="24" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 2C6.5 2 2 6.5 2 12s4.5 10 10 10 10-4.5 10-10S17.5 2 12 2zM9.8 17.3l-4.2-4.1L7 11.8l2.8 2.7L17 7.4l1.4 1.4-8.6 8.5z"></path></svg></div></span>,
#  <span class="inline-metadata-item style-scope ytd-video-meta-block">155K views</span>,
#  <span class="inline-metadata-item style-scope ytd-video-meta-block">8 months ago</span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" enable-background="new 0 0 24 24" focusable="false" height="24" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 16.5c.83 0 1.5.67 1.5 1.5s-.67 1.5-1.5 1.5-1.5-.67-1.5-1.5.67-1.5 1.5-1.5zM10.5 12c0 .83.67 1.5 1.5 1.5s1.5-.67 1.5-1.5-.67-1.5-1.5-1.5-1.5.67-1.5 1.5zm0-6c0 .83.67 1.5 1.5 1.5s1.5-.67 1.5-1.5-.67-1.5-1.5-1.5-1.5.67-1.5 1.5z"></path></svg></div></span>,
#  <span aria-label="34 minutes, 46 seconds" class="style-scope ytd-thumbnail-overlay-time-status-renderer" id="text">
#      34:46
#    </span>,
#  <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer" id="overlay-text">Now playing</span>,
#  <span aria-label="Every Minute One Person Is Eliminated by MrBeast 35,025,296 views 1 day ago 34 minutes" class="style-scope ytd-compact-video-renderer style-scope ytd-compact-video-renderer" id="video-title" title="Every Minute One Person Is Eliminated">
#              Every Minute One Person Is Eliminated
#            </span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" focusable="false" height="24" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 2C6.5 2 2 6.5 2 12s4.5 10 10 10 10-4.5 10-10S17.5 2 12 2zM9.8 17.3l-4.2-4.1L7 11.8l2.8 2.7L17 7.4l1.4 1.4-8.6 8.5z"></path></svg></div></span>,
#  <span class="inline-metadata-item style-scope ytd-video-meta-block">35M views</span>,
#  <span class="inline-metadata-item style-scope ytd-video-meta-block">1 day ago</span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" enable-background="new 0 0 24 24" focusable="false" height="24" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 16.5c.83 0 1.5.67 1.5 1.5s-.67 1.5-1.5 1.5-1.5-.67-1.5-1.5.67-1.5 1.5-1.5zM10.5 12c0 .83.67 1.5 1.5 1.5s1.5-.67 1.5-1.5-.67-1.5-1.5-1.5-1.5.67-1.5 1.5zm0-6c0 .83.67 1.5 1.5 1.5s1.5-.67 1.5-1.5-.67-1.5-1.5-1.5-1.5.67-1.5 1.5z"></path></svg></div></span>,
#  <span aria-label="24 minutes, 2 seconds" class="style-scope ytd-thumbnail-overlay-time-status-renderer" id="text">
#      24:02
#    </span>,
#  <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer" id="overlay-text">Now playing</span>,
#  <span aria-label="@FlyingBeast320 brings Beast Life to Shark Tank India | Beast Vs Sharks | Full Pitch by SET India 4,256,412 views 2 days ago 24 minutes" class="style-scope ytd-compact-video-renderer style-scope ytd-compact-video-renderer" id="video-title" title="@FlyingBeast320 brings Beast Life to Shark Tank India | Beast Vs Sharks | Full Pitch">
#              @FlyingBeast320 brings Beast Life to Shark Tank India | Beast Vs Sharks | Full Pitch
#            </span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" focusable="false" height="24" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 2C6.5 2 2 6.5 2 12s4.5 10 10 10 10-4.5 10-10S17.5 2 12 2zM9.8 17.3l-4.2-4.1L7 11.8l2.8 2.7L17 7.4l1.4 1.4-8.6 8.5z"></path></svg></div></span>,
#  <span class="inline-metadata-item style-scope ytd-video-meta-block">4.2M views</span>,
#  <span class="inline-metadata-item style-scope ytd-video-meta-block">2 days ago</span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" enable-background="new 0 0 24 24" focusable="false" height="24" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 16.5c.83 0 1.5.67 1.5 1.5s-.67 1.5-1.5 1.5-1.5-.67-1.5-1.5.67-1.5 1.5-1.5zM10.5 12c0 .83.67 1.5 1.5 1.5s1.5-.67 1.5-1.5-.67-1.5-1.5-1.5-1.5.67-1.5 1.5zm0-6c0 .83.67 1.5 1.5 1.5s1.5-.67 1.5-1.5-.67-1.5-1.5-1.5-1.5.67-1.5 1.5z"></path></svg></div></span>,
#  <span aria-label="30 minutes, 49 seconds" class="style-scope ytd-thumbnail-overlay-time-status-renderer" id="text">
#      30:49
#    </span>,
#  <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer" id="overlay-text">Now playing</span>,
#  <span aria-label="Aditya Srivastava AIR 1 IAS - UPSC CSE Topper 2023 | UPSC Mock Interview | Vajirao &amp; Reddy Institute by Vajirao and Reddy Institute 2,185,027 views 9 months ago 30 minutes" class="style-scope ytd-compact-video-renderer style-scope ytd-compact-video-renderer" id="video-title" title="Aditya Srivastava AIR 1 IAS - UPSC CSE Topper 2023 | UPSC Mock Interview | Vajirao &amp; Reddy Institute">
#              Aditya Srivastava AIR 1 IAS - UPSC CSE Topper 2023 | UPSC Mock Interview | Vajirao &amp; Reddy Institute
#            </span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" focusable="false" height="24" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 2C6.5 2 2 6.5 2 12s4.5 10 10 10 10-4.5 10-10S17.5 2 12 2zM9.8 17.3l-4.2-4.1L7 11.8l2.8 2.7L17 7.4l1.4 1.4-8.6 8.5z"></path></svg></div></span>,
#  <span class="inline-metadata-item style-scope ytd-video-meta-block">2.1M views</span>,
#  <span class="inline-metadata-item style-scope ytd-video-meta-block">9 months ago</span>,
#  <span class="yt-icon-shape style-scope yt-icon yt-spec-icon-shape"><div style="width: 100%; height: 100%; display: block; fill: currentcolor;"><svg aria-hidden="true" enable-background="new 0 0 24 24" focusable="false" height="24" style="pointer-events: none; display: inherit; width: 100%; height: 100%;" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 16.5c.83 0 1.5.67 1.5 1.5s-.67 1.5-1.5 1.5-1.5-.67-1.5-1.5.67-1.5 1.5-1.5zM10.5 12c0 .83.67 1.5 1.5 1.5s1.5-.67 1.5-1.5-.67-1.5-1.5-1.5-1.5.67-1.5 1.5zm0-6c0 .83.67 1.5 1.5 1.5s1.5-.67 1.5-1.5-.67-1.5-1.5-1.5-1.5.67-1.5 1.5z"></path></svg></div></span>,
#  <span class="yt-core-attributed-string yt-core-attributed-string--white-space-no-wrap" role="text">Show more</span>]

# %%
 
for video in  soup.find_all('a', class_='yt-simple-endpoint style-scope yt-formatted-string bold'):
    try:
        video_id = video.get('href').split('/')[-1] if video.get('href') else None
        print(video_id)
    except Exception as e:
        print(f"Error extracting video ID: {e}")

# %%
description_list = []
for video in soup.find_all('span', ):
    span = video.find('span','yt-core-attributed-string--link-inherit-color')
    if span:
        description_list.append(span.text)

# Print the description list
print(description_list)
# Out:
# ['Watch Full Video: - ', 'Watch Full Video: - ', 'Watch Full Video: - ', 'Watch Full Video: - ', 'Watch Full Video: - ']

# %%
# Extract video title
oneVideo = soup.find_all('yt-formatted-string', class_='style-scope ytd-watch-metadata')
video_title = oneVideo[0].text if oneVideo else None

# Extract video views
try:
    videoViews = soup.find('yt-animated-rolling-number', class_='animated-rolling-number-wiz style-scope ytd-watch-info-text')
    video_views = videoViews.text if videoViews else None
except Exception as e:
    video_views = None
    print(f"Error extracting views: {e}")

# Extract video descriptions
description_list = []
span = soup.find_all('span', class_='yt-core-attributed-string--link-inherit-color')
for desc in span:
    if desc:
        description_list.append(desc.text.strip())

# Concatenate all descriptions into one string
full_description = " ".join(description_list)

# Extract video ID from 'a' tag
video_id_list = []
try:
    video = soup.find_all('a', class_='yt-simple-endpoint style-scope yt-formatted-string bold')
    for vid in video:
        video_id_list.append(vid.get('href') if vid.get('href') else None)
except Exception as e:
    print(f"Error extracting video IDs: {e}")
concatenated_video_ids = "".join(video_id_list)
# Store all extracted information in a dictionary
video_details = {
    'title': video_title,
    'views': video_views,
    'description': full_description,  # Concatenated description
    'video_id': concatenated_video_ids  
}

# Print the video details
print(video_details)
# Out:
# {'title': 'A Day in the Life at IIT: Struggles & Successes 🎓 || Meet Apoorva GATE AIR 20', 'views': '', 'description': "Watch Full Video: - •\xa0Life\xa0at\xa0IIT:\xa0Struggles,\xa0Successes\xa0&\xa0E... Don't wait no more, and explore the GATE programs that are on offer now: https://gfgcdn.com/tu/U4T/ Ever wondered what a day in the life of an IITian looks like? In this video, we take you through the highs and lows of daily life at IIT, featuring Apoorva, who secured GATE AIR 20! From challenging academics to moments of success, watch as Apoorva shares their journey, struggles, and triumphs. Whether you're aiming for IIT or just curious about student life, this video gives you an inside look into the reality. Don’t forget to like, comment, and subscribe for more inspiring stories! 🎓🔥💡 #iitlife  #gatesuccess  #studentjourney  #IITStruggles  #successstory  #gatepreparation  #iitmotivation  #engineeringlife  #gateexam  #gatestudyplan  #gate2025 Watch Full Video: - •\xa0Life\xa0at\xa0IIT:\xa0Struggles,\xa0Successes\xa0&\xa0E... Don't wait no more, and explore the GATE programs that are on offer now: https://gfgcdn.com/tu/U4T/ Ever wondered what a day in the life of an IITian looks like? In this video, we take you through the highs and lows of daily life at IIT, featuring Apoorva, who secured GATE AIR 20! From challenging academics to moments of success, watch as Apoorva shares their journey, struggles, and triumphs. Whether you're aiming for IIT or just curious about student life, this video gives you an inside look into the reality. Don’t forget to like, comment, and subscribe for more inspiring stories! 🎓🔥💡 #iitlife  #gatesuccess  #studentjourney  #IITStruggles  #successstory  #gatepreparation  #iitmotivation  #engineeringlife  #gateexam  #gatestudyplan  #gate2025 Watch Full Video: - •\xa0Life\xa0at\xa0IIT:\xa0Struggles,\xa0Successes\xa0&\xa0E... Don't wait no more, and explore the GATE programs that are on offer now: https://gfgcdn.com/tu/U4T/", 'video_id': ''}

# %% [markdown]
# # Automating

# %%
import time
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# Initialize the browser
browser = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# Initialize a list to store all video details
complete_video_details = []

for video_url in df['url']:  # Iterate over the URLs in your DataFrame
    # Convert video_url to string in case it's not
    video_url = str(video_url)

    # Open the video URL in the browser
    browser.get(video_url)
    
    # Wait for the page to load
    time.sleep(2)  # Sleep for 2 seconds between requests

    # Get the page source after loading
    soup = BeautifulSoup(browser.page_source, 'html.parser')

    # Extract video title
    oneVideo = soup.find_all('yt-formatted-string', class_='style-scope ytd-watch-metadata')
    video_title = oneVideo[0].text if oneVideo else None

    # Extract video views
    try:
        videoViews = soup.find('span', class_='bold style-scope yt-formatted-string')
        video_views = videoViews.text if videoViews else None
    except Exception as e:
        video_views = None
        print(f"Error extracting views: {e}")

    # Extract video descriptions
    description_list = []
    span = soup.find_all('span', class_='yt-core-attributed-string--link-inherit-color')
    for desc in span:
        if desc:
            description_list.append(desc.text.strip())

    # Concatenate all descriptions into one string
    full_description = " ".join(description_list)

    # Extract video IDs
    video_id_list = []
    try:
        video = soup.find_all('a', class_='yt-simple-endpoint style-scope yt-formatted-string bold')
        for vid in video:
            video_id_list.append(vid.get('href') if vid.get('href') else None)
    except Exception as e:
        print(f"Error extracting video IDs: {e}")
    concatenated_video_ids = "".join(video_id_list)

    # Append the extracted information to the complete_video_details list
    complete_video_details.append({
        'title': video_title,
        'views': video_views,
        'description': full_description,  # Concatenated description
        'video_id': concatenated_video_ids,  # Use concatenated_video_ids here
        'url': video_url  # Add the video URL for reference
    })
    # print(complete_video_details)
    # print("*" * 40)

# Print the complete video details
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 25
#      22 time.sleep(2)  # Sleep for 2 seconds between requests
#      24 # Get the page source after loading
# ---> 25 soup = BeautifulSoup(browser.page_source, 'html.parser')
#      27 # Extract video title
#      28 oneVideo = soup.find_all('yt-formatted-string', class_='style-scope ytd-watch-metadata')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\bs4\__init__.py:335, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333 self.builder.initialize_soup(self)
#     334 try:
# --> 335     self._feed()
#     336     success = True
#     337     break
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\bs4\__init__.py:478, in BeautifulSoup._feed(self)
#     475 # Convert the document to Unicode.
#     476 self.builder.reset()
# --> 478 self.builder.feed(self.markup)
#     479 # Close out any unfinished strings and close all the open tags.
#     480 self.endData()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\bs4\builder\_htmlparser.py:380, in HTMLParserTreeBuilder.feed(self, markup)
#     378 parser.soup = self.soup
#     379 try:
# --> 380     parser.feed(markup)
#     381     parser.close()
#     382 except AssertionError as e:
#     383     # html.parser raises AssertionError in rare cases to
#     384     # indicate a fatal problem with the markup, especially
#     385     # when there's an error in the doctype declaration.
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\html\parser.py:111, in HTMLParser.feed(self, data)
#     105 r"""Feed data to the parser.
#     106
#     107 Call this as often as you want, with as little or as much text
#     108 as you want (may include '\n').
#     109 """
#     110 self.rawdata = self.rawdata + data
# --> 111 self.goahead(0)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\html\parser.py:171, in HTMLParser.goahead(self, end)
#     169 if startswith('<', i):
#     170     if starttagopen.match(rawdata, i): # < + letter
# --> 171         k = self.parse_starttag(i)
#     172     elif startswith("</", i):
#     173         k = self.parse_endtag(i)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\html\parser.py:338, in HTMLParser.parse_starttag(self, i)
#     336     self.handle_startendtag(tag, attrs)
#     337 else:
# --> 338     self.handle_starttag(tag, attrs)
#     339     if tag in self.CDATA_CONTENT_ELEMENTS:
#     340         self.set_cdata_mode(tag)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\bs4\builder\_htmlparser.py:141, in BeautifulSoupHTMLParser.handle_starttag(self, name, attrs, handle_empty_element)
#     136 sourceline, sourcepos = self.getpos()
#     137 tag = self.soup.handle_starttag(
#     138     name, None, None, attr_dict, sourceline=sourceline,
#     139     sourcepos=sourcepos
#     140 )
# --> 141 if tag and tag.is_empty_element and handle_empty_element:
#     142     # Unlike other parsers, html.parser doesn't send separate end tag
#     143     # events for empty-element tags. (It's handled in
#     144     # handle_startendtag, but only if the original markup looked like
#     145     # <tag/>.)
#     146     #
#     147     # So we need to call handle_endtag() ourselves. Since we
#     148     # know the start event is identical to the end event, we
#     149     # don't want handle_endtag() to cross off any previous end
#     150     # events for tags of this name.
#     151     self.handle_endtag(name, check_already_closed=False)
#     153     # But we might encounter an explicit closing tag for this tag
#     154     # later on. If so, we want to ignore it.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\bs4\element.py:1371, in Tag.is_empty_element(self)
#    1368         setattr(clone, attr, getattr(self, attr))
#    1369     return clone
# -> 1371 @property
#    1372 def is_empty_element(self):
#    1373     """Is this tag an empty-element tag? (aka a self-closing tag)
#    1374
#    1375     A tag that has contents is never an empty-element tag.
#    (...)
#    1384     then any tag with no contents is an empty-element tag.
#    1385     """
#    1386     return len(self.contents) == 0 and self.can_be_empty_element
#
# KeyboardInterrupt:

# %%
video_details_df = pd.DataFrame(complete_video_details)
 
video_details_df.to_csv("analysis.csv", index=False)
