# %%
# !pip install numpy 
# !pip install pandas 
# !pip install chromedriver_binary
# !pip install beautifulsoup4
# !pip install selenium
# !pip install webdriver-manager
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import chromedriver_binary
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
browser = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
browser.get('https://stock-pictures.netlify.app')

# %%
soup  = BeautifulSoup(browser.page_source,'html.parser')

# %%
soup.find('img').get('src')
# Out:
# 'https://cdn.pixabay.com/photo/2022/03/06/05/30/clouds-7050884__480.jpg'

# %%
data = []

for sp in soup.find_all('div',class_='container'):
    img_link = sp.find('img').get('src')
    tags = list(set(sp.find('div',class_='tags').text[7:].split(' ')))
    likes = int(sp.find(class_= 'likes-comments').find_all('span')[0].text.strip()[:-6])
    comments = int(sp.find(class_= 'likes-comments').find_all('span')[1].text.strip()[:-8])
    print(tags)
    print(likes)
    print(comments)
    print("*"*10)
    data.append([img_link, tags, likes, comments])

df = pd.DataFrame(data, columns = ['img_link', 'tags', 'likes', 'comments'])
df.to_csv('images.csv', index = False)
# Out:
# ['Blue', 'Sky,', 'Clouds,', 'Atmosphere,', 'Sky']
# 196
# 55
# **********
# ['Ornithology,', 'Bird,', 'Hummingbird']
# 76
# 20
# **********
# ['Rainbow,', 'Rainfall,', 'Subtropical', 'Sea,']
# 282
# 106
# **********
# ['Road,', 'Cherry', 'Japan,', 'Sakura', 'Blossoms,']
# 42
# 11
# **********
# ['Plant', 'Cape', 'Flower,', 'Marguerite,']
# 39
# 15
# **********
# ['Under', 'The', 'Rest', 'Tree', 'Relaxing']
# 522
# 108
# **********
# ['Wild', 'Rabbit,', 'Cottontail', 'Grass']
# 51
# 10
# **********
# ['Spring,', 'Plant', 'Flowers,', 'Crocus,']
# 135
# 44
# **********
# ['Vacation,', 'Table', 'Coffee,', 'Drink,', 'Café,']
# 26
# 5
# **********
# ['Light', 'Nature,', 'Waterfall,', 'Epic,', 'Fall,']
# 96
# 21
# **********
# ['Sunrise,', 'Morning,', 'Nature', 'Field,', 'Dawn,']
# 807
# 131
# **********
# ['Birdwatching,', 'Bird,', 'Robin,', 'Animal']
# 69
# 19
# **********
# ['Bloom', 'Spring', 'Soil,', 'Seedlings,', 'Flowers,']
# 42
# 9
# **********
# ['Road,', 'Highway,', 'Hills', 'Countryside,']
# 53
# 14
# **********
# ['Monochrome,', 'Bridge,', 'City', 'Cityscape,']
# 45
# 13
# **********
# ['Water', 'Cherry', 'Spring,', 'Blossoms,', 'Sakura,']
# 70
# 12
# **********
# ['Background,', 'Art', 'Easter,', 'Eggs,', 'Template,']
# 5
# 2
# **********
# ['Ornithology,', 'Bird,', 'Chat,', 'Indian', 'Species']
# 171
# 53
# **********
# ['Village,', 'Town,', 'Winter,', 'Season', 'Night,']
# 109
# 15
# **********
# ['Flower,', 'Blossom,', 'Viola,', 'Pansy,', 'Bloom']
# 55
# 36
# **********
# ['Port,', 'Vacations', 'Architecture,', 'Lake,']
# 276
# 49
# **********
# ['Plant', 'Sunflowers,', 'Flowers,']
# 54
# 21
# **********
# ['Morning', 'Coffee,', 'Spring,', 'Flowers,']
# 40
# 10
# **********
# ['Lake,', 'Roys', 'Mountains', 'Wanaka,', 'Peak,']
# 69
# 19
# **********
# ['you', 'and', 'for', 'many', 'downloads', 'likes.', 'Thank', 'everyone.', 'you,']
# 197
# 0
# **********
# ['Exploration', 'Outdoors,', 'Nature,', 'Beach,']
# 272
# 150
# **********
# ['of', 'Jutland.', 'Shot', 'The', 'Coast', 'Danish', 'during', 'West', 'sunset.']
# 48
# 11
# **********
# ['Gentoo', 'Penguin,', 'Bird,', 'Animal']
# 93
# 22
# **********
# ['Heaven,', 'Beach,', 'Sea,', 'Water,', 'Lantern,', 'Tree']
# 243
# 31
# **********
# ['Spring,', 'Bunny', 'Easter', 'Easter,']
# 17
# 10
# **********
# ['on', 'trees', 'brown', 'lake', 'rock', 'daytime', 'during', 'green', 'formation']
# 3098
# 495
# **********
# ['Attraction,', 'Tourist', 'Travel', 'Eiffel', 'Tower,']
# 83
# 21
# **********
# ['Stones', 'Standing', 'Menhir,', 'Clouds,', 'Stones,']
# 64
# 49
# **********
# ['Road,', 'Path', 'Frost,', 'Trees,', 'Winter,', 'Snow,']
# 133
# 24
# **********
# ['Bird,', 'Woodpecker']
# 28
# 20
# **********
# ['Retro,', 'Music,', 'Tape,', 'Cassette,', 'Classic']
# 134
# 20
# **********
# ['Mills,', 'Energy,', 'Clouds,', 'Wind', 'Power']
# 144
# 101
# **********
# ['Tourism,', 'Tartini,', 'Travel,', 'Square,', 'Piran']
# 70
# 19
# **********
# ['Nest,', 'Easter', 'Colored', 'Eggs', 'Eggs,']
# 29
# 0
# **********
# ['Season,', 'Travel', 'Nature,', 'Winter,', 'Outdoors,']
# 111
# 24
# **********
# ['Glacier,', 'Glaciers,', 'Glacier', 'Dying', 'Melting']
# 36
# 27
# **********
# ['Tropical,', 'Green,', 'Nature', 'Jungle,', 'Forest,']
# 135
# 22
# **********
# ['Tulip,', 'Flower,', 'Blossom,', 'Bloom,', 'Petals']
# 92
# 35
# **********
# ['Petals', 'Pink', 'Flowers,']
# 62
# 0
# **********
# ['Passiflora,', 'Passion', 'Flower', 'Flower,']
# 97
# 66
# **********
# ['Faith,', 'Prayer,', 'Blessing', 'Religion,', 'Hope,']
# 175
# 57
# **********
# ['Galaxy,', 'Space,', 'Cosmos', 'Universe,', 'Star,']
# 45
# 40
# **********
# ['Insect,', 'Nature,', 'Dragonfly,', 'Macro']
# 19
# 3
# **********

# %%
df.head()
# Out:
#                                             img_link  \
# 0  https://cdn.pixabay.com/photo/2022/03/06/05/30...
# 1  https://cdn.pixabay.com/photo/2022/04/07/11/45...
# 2  https://cdn.pixabay.com/photo/2022/02/28/15/28...
# 3  https://cdn.pixabay.com/photo/2022/04/04/02/52...
# 4  https://cdn.pixabay.com/photo/2022/04/09/18/06...
#
#                                          tags  likes  comments
# 0     [Blue, Sky,, Clouds,, Atmosphere,, Sky]    196        55
# 1          [Ornithology,, Bird,, Hummingbird]     76        20
# 2    [Rainbow,, Rainfall,, Subtropical, Sea,]    282       106
# 3  [Road,, Cherry, Japan,, Sakura, Blossoms,]     42        11
# 4         [Plant, Cape, Flower,, Marguerite,]     39        15
