# %%
# !pip install numpy 
# !pip install pandas 
# !pip install chromedriver_binary
# !pip install beautifulsoup4
# !pip install selenium
# !pip install webdriver-manager
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import chromedriver_binary
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
browser = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
browser.get('https://stock-pictures.netlify.app')

# %%
soup  = BeautifulSoup(browser.page_source,'html.parser')

# %%
soup.find('img').get('src')
# Out:
# 'https://cdn.pixabay.com/photo/2022/03/06/05/30/clouds-7050884__480.jpg'

# %%
data = []

for sp in soup.find_all('div',class_='container'):
    img_link = sp.find('img').get('src')
    tags = list(set(sp.find('div',class_='tags').text[7:].split(' ')))
    likes = int(sp.find(class_= 'likes-comments').find_all('span')[0].text.strip()[:-6])
    comments = int(sp.find(class_= 'likes-comments').find_all('span')[1].text.strip()[:-8])
    print(tags)
    print(likes)
    print(comments)
    print("*"*10)
    data.append([img_link, tags, likes, comments])

df = pd.DataFrame(data, columns = ['img_link', 'tags', 'likes', 'comments'])
df.to_csv('images.csv', index = False)
# Out:
# ['Sky,', 'Sky', 'Atmosphere,', 'Blue', 'Clouds,']
# 196
# 55
# **********
# ['Ornithology,', 'Bird,', 'Hummingbird']
# 76
# 20
# **********
# ['Rainbow,', 'Subtropical', 'Sea,', 'Rainfall,']
# 282
# 106
# **********
# ['Blossoms,', 'Sakura', 'Japan,', 'Road,', 'Cherry']
# 42
# 11
# **********
# ['Flower,', 'Plant', 'Cape', 'Marguerite,']
# 39
# 15
# **********
# ['Rest', 'Under', 'Relaxing', 'Tree', 'The']
# 522
# 108
# **********
# ['Cottontail', 'Wild', 'Grass', 'Rabbit,']
# 51
# 10
# **********
# ['Spring,', 'Plant', 'Flowers,', 'Crocus,']
# 135
# 44
# **********
# ['Vacation,', 'Coffee,', 'Café,', 'Table', 'Drink,']
# 26
# 5
# **********
# ['Fall,', 'Waterfall,', 'Nature,', 'Light', 'Epic,']
# 96
# 21
# **********
# ['Morning,', 'Nature', 'Field,', 'Sunrise,', 'Dawn,']
# 807
# 131
# **********
# ['Bird,', 'Robin,', 'Animal', 'Birdwatching,']
# 69
# 19
# **********
# ['Seedlings,', 'Spring', 'Bloom', 'Soil,', 'Flowers,']
# 42
# 9
# **********
# ['Highway,', 'Countryside,', 'Hills', 'Road,']
# 53
# 14
# **********
# ['Bridge,', 'City', 'Cityscape,', 'Monochrome,']
# 45
# 13
# **********
# ['Blossoms,', 'Water', 'Sakura,', 'Cherry', 'Spring,']
# 70
# 12
# **********
# ['Template,', 'Easter,', 'Eggs,', 'Background,', 'Art']
# 5
# 2
# **********
# ['Bird,', 'Indian', 'Chat,', 'Species', 'Ornithology,']
# 171
# 53
# **********
# ['Season', 'Town,', 'Village,', 'Night,', 'Winter,']
# 109
# 15
# **********
# ['Viola,', 'Flower,', 'Bloom', 'Blossom,', 'Pansy,']
# 55
# 36
# **********
# ['Port,', 'Lake,', 'Vacations', 'Architecture,']
# 276
# 49
# **********
# ['Sunflowers,', 'Plant', 'Flowers,']
# 54
# 21
# **********
# ['Coffee,', 'Flowers,', 'Morning', 'Spring,']
# 40
# 10
# **********
# ['Wanaka,', 'Peak,', 'Roys', 'Lake,', 'Mountains']
# 69
# 19
# **********
# ['and', 'for', 'you,', 'downloads', 'Thank', 'many', 'everyone.', 'likes.', 'you']
# 197
# 0
# **********
# ['Outdoors,', 'Nature,', 'Beach,', 'Exploration']
# 272
# 150
# **********
# ['Danish', 'West', 'Shot', 'during', 'sunset.', 'Jutland.', 'of', 'Coast', 'The']
# 48
# 11
# **********
# ['Bird,', 'Gentoo', 'Animal', 'Penguin,']
# 93
# 22
# **********
# ['Beach,', 'Water,', 'Sea,', 'Heaven,', 'Lantern,', 'Tree']
# 243
# 31
# **********
# ['Easter,', 'Spring,', 'Easter', 'Bunny']
# 17
# 10
# **********
# ['daytime', 'brown', 'rock', 'green', 'lake', 'during', 'on', 'formation', 'trees']
# 3098
# 495
# **********
# ['Tourist', 'Attraction,', 'Travel', 'Tower,', 'Eiffel']
# 83
# 21
# **********
# ['Standing', 'Stones,', 'Stones', 'Clouds,', 'Menhir,']
# 64
# 49
# **********
# ['Frost,', 'Road,', 'Path', 'Snow,', 'Trees,', 'Winter,']
# 133
# 24
# **********
# ['Bird,', 'Woodpecker']
# 28
# 20
# **********
# ['Music,', 'Cassette,', 'Classic', 'Retro,', 'Tape,']
# 134
# 20
# **********
# ['Power', 'Clouds,', 'Energy,', 'Mills,', 'Wind']
# 144
# 101
# **********
# ['Travel,', 'Piran', 'Tartini,', 'Square,', 'Tourism,']
# 70
# 19
# **********
# ['Nest,', 'Colored', 'Eggs,', 'Easter', 'Eggs']
# 29
# 0
# **********
# ['Travel', 'Outdoors,', 'Season,', 'Nature,', 'Winter,']
# 111
# 24
# **********
# ['Glacier,', 'Glaciers,', 'Dying', 'Melting', 'Glacier']
# 36
# 27
# **********
# ['Tropical,', 'Forest,', 'Jungle,', 'Nature', 'Green,']
# 135
# 22
# **********
# ['Bloom,', 'Tulip,', 'Flower,', 'Blossom,', 'Petals']
# 92
# 35
# **********
# ['Pink', 'Flowers,', 'Petals']
# 62
# 0
# **********
# ['Flower', 'Flower,', 'Passiflora,', 'Passion']
# 97
# 66
# **********
# ['Hope,', 'Blessing', 'Faith,', 'Prayer,', 'Religion,']
# 175
# 57
# **********
# ['Universe,', 'Space,', 'Cosmos', 'Star,', 'Galaxy,']
# 45
# 40
# **********
# ['Nature,', 'Insect,', 'Macro', 'Dragonfly,']
# 19
# 3
# **********

# %%
df.head()
# Out:
#                                             img_link  \
# 0  https://cdn.pixabay.com/photo/2022/03/06/05/30...
# 1  https://cdn.pixabay.com/photo/2022/04/07/11/45...
# 2  https://cdn.pixabay.com/photo/2022/02/28/15/28...
# 3  https://cdn.pixabay.com/photo/2022/04/04/02/52...
# 4  https://cdn.pixabay.com/photo/2022/04/09/18/06...
#
#                                          tags  likes  comments
# 0     [Sky,, Sky, Atmosphere,, Blue, Clouds,]    196        55
# 1          [Ornithology,, Bird,, Hummingbird]     76        20
# 2    [Rainbow,, Subtropical, Sea,, Rainfall,]    282       106
# 3  [Blossoms,, Sakura, Japan,, Road,, Cherry]     42        11
# 4         [Flower,, Plant, Cape, Marguerite,]     39        15
