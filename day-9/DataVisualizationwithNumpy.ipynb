# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 4 * np.pi, 100)
print(x)

y = np.sin(x)
cosy = np.cos(x)
plt.plot(x,y,"o",linestyle="--", color = 'red', markersize = 5,alpha = .45)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title('Basic Line Plot ')
plt.plot(x, y, "o", linestyle="--", color='red', markersize=5, alpha=0.9, label="sin(x)")
plt.plot(x, cosy, "o", linestyle="--", color='blue', markersize=5, alpha=0.9, label="cos(x)")
plt.legend() 
plt.plot()

plt.plot(x,cosy,"o",linestyle="--", color = 'blue', markersize = 5,alpha = .33)
plt.plot()
# Out:
# [ 0.          0.12693304  0.25386607  0.38079911  0.50773215  0.63466518
#   0.76159822  0.88853126  1.01546429  1.14239733  1.26933037  1.3962634
#   1.52319644  1.65012947  1.77706251  1.90399555  2.03092858  2.15786162
#   2.28479466  2.41172769  2.53866073  2.66559377  2.7925268   2.91945984
#   3.04639288  3.17332591  3.30025895  3.42719199  3.55412502  3.68105806
#   3.8079911   3.93492413  4.06185717  4.1887902   4.31572324  4.44265628
#   4.56958931  4.69652235  4.82345539  4.95038842  5.07732146  5.2042545
#   5.33118753  5.45812057  5.58505361  5.71198664  5.83891968  5.96585272
#   6.09278575  6.21971879  6.34665183  6.47358486  6.6005179   6.72745093
#   6.85438397  6.98131701  7.10825004  7.23518308  7.36211612  7.48904915
#   7.61598219  7.74291523  7.86984826  7.9967813   8.12371434  8.25064737
#   8.37758041  8.50451345  8.63144648  8.75837952  8.88531256  9.01224559
#   9.13917863  9.26611167  9.3930447   9.51997774  9.64691077  9.77384381
# ...

# %% [markdown]
# # Scatter Plot

# %%
x = np.random.rand(500)
y = np.random.rand(500)  
z=np.random.rand(500) # used for colors 

x1 = np.random.rand(200) + .5
y1 = np.random.rand(200) + .5  # showing this scatter thing as +2 in x axis to differenntiate



plt.scatter(x1,y1, marker = 'o', alpha = .7)
plt.scatter(x,y,marker='o' , c=z , cmap='viridis')

plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Basic Scatte Plot ')
plt.legend()
plt.colorbar()
plt.show()
# Out:
# C:\Users\aspha\AppData\Local\Temp\ipykernel_16140\3606851270.py:16: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# #  Hexbinning Scatter Plot

# %%
x1 = np.random.rand(10000)
y1 = np.random.rand(10000)
plt.hexbin(x1,y1,gridsize= 20) 

plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Hexbining Plot')
plt.colorbar()
plt.show()

# %%
data = np.random.rand(10,5)
print(data)
print()
print(data[ : ,0])
print()


plt.bar(np.arange(10), data[:,0] + data[:,1],label = 'D-2') # stacked bar should be above 
plt.bar(np.arange(10), data[:,0], label = 'D-1')          # all sum of rows of col0 only
# Out:
# [[7.52394974e-01 2.08997595e-01 7.50029712e-01 5.41261661e-02
#   6.16518092e-01]
#  [8.54163780e-01 3.44993146e-01 9.94793245e-02 2.92251010e-01
#   1.76457108e-01]
#  [7.36551952e-01 5.24631710e-01 2.07381143e-01 8.20188835e-03
#   2.33606052e-01]
#  [2.44552752e-01 6.80600623e-01 9.93072255e-01 1.06191409e-01
#   6.65049800e-02]
#  [1.21234911e-01 9.10690960e-02 4.44708582e-01 6.44236638e-01
#   5.28697613e-01]
#  [4.26682900e-01 1.00161375e-02 8.58959795e-01 6.34902707e-01
#   2.20351894e-01]
#  [9.96423137e-02 9.77719936e-02 9.66513117e-01 1.39158743e-01
#   9.76895226e-01]
#  [3.35344509e-01 5.40035336e-01 9.66529914e-01 1.74952092e-01
#   2.88564667e-01]
#  [8.65599163e-01 8.98134422e-01 1.10122862e-01 9.53604837e-04
#   5.67592827e-01]
#  [6.38464732e-01 6.28698206e-01 1.42362182e-01 3.08092079e-01
#   3.24251906e-01]]
#
# [0.75239497 0.85416378 0.73655195 0.24455275 0.12123491 0.4266829
#  0.09964231 0.33534451 0.86559916 0.63846473]
# <BarContainer object of 10 artists>

# %% [markdown]
# # Grouped Bar Graph

# %%
data = np.array([
    [10,20,30],
    [40,50,60]
])

width = 0.2
x= np.arange(2)

plt.bar(x-width , data[:,0] , width, label  = 'D-1')
plt.bar(x , data[:,1] , width, label  = 'D-2')
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# #  Histogram

# %%
data1 = np.random.randn(100000)
data2 = np.random.randn(100000) + 2
 # bins is the no of intervals 
plt.hist(data1, bins = 100, alpha = .7, label = 'D1', color='red')
plt.hist(data2, bins = 100, alpha = .7, label = 'D2')
plt.legend()
plt.show()

# %% [markdown]
# # Cumulative Histogram

# %%
data = np.random.randn(1000000)

plt.hist(data, bins = 1000, cumulative = True)
plt.show()

# %% [markdown]
# # Box Plot

# %%
data = np.random.randn(100,5)
# print(data)

plt.boxplot(data , labels= ['D-1','D-2','D-3','D-4','D-5'] , vert= False )
plt.show()
# oragnge line is the median of the values
# Out:
# C:\Users\aspha\AppData\Local\Temp\ipykernel_16140\1981379844.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data , labels= ['D-1','D-2','D-3','D-4','D-5'] , vert= False )

# %% [markdown]
# # Heatmap

# %%
data = np.random.rand(10,10)
plt.imshow(data )
plt.colorbar()
plt.show()

# %% [markdown]
# # Pie chart

# %%
labels = ['Python', 'C++', 'Java', 'JavaScript', 'PHP']
sizes =  [21.3,        14.6 , 9.2,     8.5,       7.7]
explode = (0.13,        .1,    0,       0,           0)
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightpink']


plt.title("Programming Language Popularity")
# decimal palces is autopct 
plt.pie(sizes, colors=colors, labels=labels, autopct='%1.1f%%', shadow=True, explode=explode ,startangle=140)
plt.show()
